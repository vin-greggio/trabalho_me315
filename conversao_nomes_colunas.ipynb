# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import polars as pl
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('/content/drive/MyDrive/grupo I me315/dados_anos.db')

# %%
pd.read_sql('SELECT `TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)`,`TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)`,`TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)`,`estacao` FROM dados_2018', conn)

# %%
cursor = conn.cursor()
'''
for i in range(2001,2023):
  cursor.execute(f"ALTER TABLE dados_{i} RENAME COLUMN `TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)` TO bulbo_seco;")

print(cursor.fetchall)
'''
# Out:
# '\nfor i in range(2001,2023):\n  cursor.execute(f"ALTER TABLE dados_{i} RENAME COLUMN `TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)` TO bulbo_seco;")\n\nprint(cursor.fetchall)\n'

# %%
for i in range(2019,2025):
  cursor.execute(f"ALTER TABLE dados_{i} RENAME COLUMN `Data` TO data;")

# %%
pd.read_sql('SELECT * FROM dados_2018 WHERE bulbo_seco IS NOT NULL ORDER BY bulbo_seco DESC LIMIT 5',conn)
# Out:
#          data HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2018-09-04      20:00                               0.0
# 1  2018-10-11      15:00                               0.0
# 2  2018-09-07      17:00                               0.0
# 3  2018-10-23      16:00                               0.0
# 4  2018-09-19      17:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              958.9
# 1                                              963.0
# 2                                              963.5
# 3                                              962.7
# 4                                              961.0
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            958.9
# 1                                            964.1
# 2                                            964.6
# 3                                            963.8
# ...

# %%
pd.read_sql('SELECT * FROM dados_2024 WHERE bulbo_seco IS NOT NULL ORDER BY bulbo_seco DESC LIMIT 5',conn)
# Out:
#          data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2024/10/06  1800 UTC                              0.0
# 1  2024/10/07  1800 UTC                              0.0
# 2  2024/10/06  1800 UTC                              0.0
# 3  2024/10/07  1700 UTC                              0.0
# 4  2024/10/06  1800 UTC                              0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              984.5
# 1                                              987.9
# 2                                              948.3
# 3                                              987.0
# 4                                              994.7
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            986.2
# 1                                            989.2
# 2                                            949.3
# 3                                            988.5
# ...

# %% [markdown]
# for i in range(2001,2025):
#   print(pd.read_sql(f"""SELECT bulbo_seco,data,estacao
#   FROM dados_{i}
#   WHERE bulbo_seco IS NOT NULL
#   ORDER BY bulbo_seco DESC
#   LIMIT 5""",conn))

# %%
cursor.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-00637d5a1a7a> in <cell line: 1>()
# ----> 1 cursor.commit()
#
# AttributeError: 'sqlite3.Cursor' object has no attribute 'commit'
